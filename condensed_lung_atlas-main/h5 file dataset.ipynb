# %%
import pandas as pd

# %%
with pd.HDFStore('./condensed_lung_atlas.h5') as h5:
    df = pd.concat(map(h5.get, h5.keys()), axis=1)

# %%
df
# Out:
#                                            Early Car4- capillaries_Hurskainen2021_P14  \
# cell_type_dataset_timepoint                                                    3418.0
# Adventitial fibroblast_ACZ_P21                                                    NaN
# Adventitial fibroblast_ACZ_P7                                                     NaN
# Adventitial fibroblast_Hurskainen2021_P14                                         NaN
# Adventitial fibroblast_Hurskainen2021_P3                                          NaN
# ...                                                                               ...
# Vascular smooth muscle                                                            NaN
# Venous EC                                                                         NaN
# basophil                                                                          NaN
# mast cell                                                                         NaN
# ...

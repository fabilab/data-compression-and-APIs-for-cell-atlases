# %%
import h5py
import numpy as np
import pandas as pd
import scanpy as sc
from scipy.cluster.hierarchy import linkage,leaves_list, dendrogram
from scipy.spatial.distance import pdist, euclidean
from scipy.special import comb
import re
import json

# %%
h5_data = h5py.File('./output/condensed_lung_atlas_in_cpm.h5',"r")

# %%
h5_data.keys()
# Out:
# <KeysViewHDF5 ['celltype', 'celltype_dataset', 'celltype_dataset_timepoint', 'celltype_timepoint']>

# %%
h5_data['celltype'].keys()
# Out:
# <KeysViewHDF5 ['cell_count', 'gene_expression_average', 'gene_proportion_expression']>

# %%
np.array(h5_data['celltype']['gene_proportion_expression']['block0_values'])
# Out:
# array([[0.011765 , 0.2018   , 0.1095   , ..., 0.       , 0.       ,
#         0.000905 ],
#        [0.01349  , 0.0501   , 0.01927  , ..., 0.       , 0.       ,
#         0.       ],
#        [0.0101   , 0.1685   , 0.06198  , ..., 0.       , 0.0004592,
#         0.       ],
#        ...,
#        [0.02563  , 0.       , 0.       , ..., 0.       , 0.       ,
#         0.00641  ],
#        [0.125    , 0.       , 0.       , ..., 0.       , 0.       ,
#         0.       ],
#        [0.002802 , 0.007282 , 0.00616  , ..., 0.002802 , 0.       ,
#         0.0005603]], dtype=float16)

# %%
# gives the name of dataset we want as an input
# celltype / celltype_dataset / celltype_dataset_timepoint
def read_file_average(df_type):
    with h5py.File('./output/condensed_lung_atlas_in_cpm.h5',"r") as h5_data:
    
        df = pd.DataFrame(
                data=np.array(h5_data[df_type]['gene_expression_average']['block0_values']).astype(np.float32),
                index=np.array(h5_data[df_type]['gene_expression_average']['axis1'].asstr()),
                columns=np.array(h5_data[df_type]['gene_expression_average']['axis0'].asstr()),
            ).T
    return df

# %%
def read_file(df_type):
    with h5py.File('./output/condensed_lung_atlas_in_cpm.h5',"r") as h5_data:
    
        df = pd.DataFrame(
                data=np.array(h5_data[df_type]['gene_proportion_expression']['block0_values']).astype(np.float32),
                index=np.array(h5_data[df_type]['gene_proportion_expression']['axis1'].asstr()),
                columns=np.array(h5_data[df_type]['gene_proportion_expression']['axis0'].asstr()),
            ).T
    return df

# %%
df = read_file('celltype')

# %%
df_average = read_file_average('celltype')

# %%
df.loc['Car4']
# Out:
# Adventitial fibroblast                       0.025345
# Airway smooth muscle                         0.021194
# Alveolar fibroblast                          0.036743
# Alveolar type I                              0.018936
# Alveolar type II                             0.027313
# Arterial EC I                                0.031860
# Arterial EC II                               0.039215
# B cell                                       0.013855
# Car4+ capillaries                            0.987305
# DC I                                         0.025284
# DC II                                        0.059998
# DC III                                       0.010307
# Early Car4- capillaries                      0.319336
# Early adventitial fibroblast                 0.018616
# Early airway smooth muscle                   0.017517
# Early alveolar fibroblast                    0.032715
# Fibroblast precursor                         0.007835
# IL cell                                      0.027771
# Late Car4- capillaries                       0.345215
# Lymphatic EC                                 0.049530
# Mac I                                        0.139893
# Mac II                                       0.069763
# Mac III                                      0.618652
# Mac IV                                       0.023926
# Mac V                                        0.017746
# Myofibroblast                                0.020264
# Myofibroblast and smooth muscle precursor    0.012497
# NK cell                                      0.019669
# Nonproliferative embryonic EC                0.064514
# Pericyte                                     0.023026
# Proliferating fibroblast                     0.011627
# Proliferating myofibroblast                  0.017853
# Proliferating pericyte                       0.000000
# Proliferative EC                             0.184082
# Striated muscle                              0.052643
# T cell                                       0.018066
# Vascular smooth muscle                       0.013092
# Venous EC                                    0.059418
# basophil                                     0.012817
# mast cell                                    0.000000
# neutrophil                                   0.013443
# Name: Car4, dtype: float32

# %%
df_average
# Out:
#                Adventitial fibroblast  Airway smooth muscle  \
# 0610005C13Rik                0.379639              2.013672
# 0610007C21Rik               84.812500             25.203125
# 0610007L01Rik               34.062500              8.250000
# 0610007N19Rik               48.437500              8.929688
# 0610007P08Rik                7.171875              7.187500
# ...                               ...                   ...
# n-R5s54                      0.000000              0.004101
# n-R5s67                      0.007317              0.117249
# n-R5s68                      0.000000              0.000000
# n-R5s8                       0.000000              0.000000
# n-R5s87                      0.084229              0.000000
#
#                Alveolar fibroblast  Alveolar type I  Alveolar type II  \
# 0610005C13Rik             1.431641         0.364014          0.726562
# 0610007C21Rik            97.062500         1.244141         14.835938
# 0610007L01Rik            23.437500         0.421875          7.386719
# 0610007N19Rik            48.156250         0.000000          3.205078
# 0610007P08Rik             7.972656         0.000000          2.726562
# ...                            ...              ...               ...
# n-R5s54                   0.015205         0.000000          0.000000
# n-R5s67                   0.035767         0.000000          0.000000
# n-R5s68                   0.000000         0.000000          0.000000
# n-R5s8                    0.013527         0.000000          0.000000
# n-R5s87                   0.000000         0.000000          0.000000
#
#                Arterial EC I  Arterial EC II     B cell  Car4+ capillaries  \
# 0610005C13Rik       3.193359        0.014755   0.176514           0.235596
# 0610007C21Rik       4.570312       70.062500  32.718750          70.750000
# 0610007L01Rik       0.000000        4.519531  17.718750          27.343750
# 0610007N19Rik       0.000000        3.279297   0.793945           2.554688
# 0610007P08Rik       0.000000        7.105469   2.048828           6.804688
# ...                      ...             ...        ...                ...
# n-R5s54             0.000000        0.000000   0.000386           0.000000
# n-R5s67             0.008865        0.073853   0.125854           0.322998
# n-R5s68             0.000000        0.000000   0.001127           0.000000
# n-R5s8              0.000000        0.000000   0.000000           0.056854
# n-R5s87             0.343018        0.000000   0.000135           0.000000
#
#                      DC I  ...  Proliferating myofibroblast  \
# 0610005C13Rik    0.061218  ...                     0.099731
# 0610007C21Rik  110.625000  ...                     0.000000
# 0610007L01Rik   68.875000  ...                     0.000000
# 0610007N19Rik    0.000000  ...                     0.000000
# 0610007P08Rik   14.195312  ...                     0.000000
# ...                   ...  ...                          ...
# n-R5s54          0.000000  ...                     0.000000
# n-R5s67          0.059479  ...                     0.022858
# n-R5s68          0.000000  ...                     0.000000
# n-R5s8           0.000000  ...                     0.000000
# n-R5s87          0.000000  ...                     0.039154
#
#                Proliferating pericyte  Proliferative EC  Striated muscle  \
# 0610005C13Rik                0.250244          0.550781         0.000000
# 0610007C21Rik                0.000000          0.000000        25.562500
# 0610007L01Rik                0.000000          0.000000         3.824219
# 0610007N19Rik                0.000000          0.000000         0.000000
# 0610007P08Rik                0.000000          0.000000         0.000000
# ...                               ...               ...              ...
# n-R5s54                      0.000000          0.000000         0.000000
# n-R5s67                      0.000000          0.116882         0.000000
# n-R5s68                      0.000000          0.000000         0.000000
# n-R5s8                       0.000000          0.043182         0.000000
# n-R5s87                      0.000000          0.000000         0.000000
#
#                   T cell  Vascular smooth muscle  Venous EC  basophil  \
# 0610005C13Rik   0.683105                0.023193   0.110229  0.091736
# 0610007C21Rik  17.546875                2.630859   3.621094  0.000000
# 0610007L01Rik  11.242188                0.776367   0.000000  0.000000
# 0610007N19Rik   0.000000                1.345703   0.000000  0.000000
# 0610007P08Rik   1.659180                0.000000   0.000000  0.000000
# ...                  ...                     ...        ...       ...
# n-R5s54         0.000585                0.030884   0.011482  0.340088
# n-R5s67         0.066895                0.173096   0.096375  0.000000
# n-R5s68         0.000000                0.000000   0.000000  0.000000
# n-R5s8          0.000000                0.048553   0.091675  0.000000
# n-R5s87         0.090210                0.003309   0.003569  1.100586
#
#                mast cell  neutrophil
# 0610005C13Rik   0.090271    0.006596
# 0610007C21Rik   0.000000    5.058594
# 0610007L01Rik   0.000000    5.898438
# 0610007N19Rik   0.000000    0.000000
# 0610007P08Rik   0.000000    0.000000
# ...                  ...         ...
# n-R5s54         0.000000    0.000202
# n-R5s67         0.000000    0.000000
# n-R5s68         0.000000    0.460938
# n-R5s8          0.000000    0.000000
# n-R5s87         0.000000    0.037506
#
# [29781 rows x 41 columns]

# %%
gene="Car4"
mylist = ["Idjd,HHH,shi"]
lower(gene)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 gene="Car4"
#       2 mylist = ["Idjd,HHH,shi"]
# ----> 3 lower(gene)
#
# NameError: name 'lower' is not defined

# %%
i = 'ACZ'
columns_with_this_dataset = [col_name for col_name in df.columns if i in col_name]
df.loc[[gene]][['Adventitial fibroblast Hurskainen2021_P7']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 i = 'ACZ'
#       2 columns_with_this_dataset = [col_name for col_name in df.columns if i in col_name]
# ----> 3 df.loc[[gene]][['Adventitial fibroblast Hurskainen2021_P7']]
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Adventitial fibroblast Hurskainen2021_P7'], dtype='object')] are in the [columns]"

# %%
df = read_file('celltype_dataset_timepoint')
# gene = 'Car4'
# filtered_df = df.filter(items=[gene],axis=0)
# filtered_df
df
# Out:
#                Adventitial fibroblast_ACZ_P21  Adventitial fibroblast_ACZ_P7  \
# 0610005C13Rik                        0.074402                            0.0
# 0610007C21Rik                        0.000000                            0.0
# 0610007L01Rik                        0.000000                            0.0
# 0610007N19Rik                        0.000000                            0.0
# 0610007P08Rik                        0.000000                            0.0
# ...                                       ...                            ...
# n-R5s54                              0.000000                            0.0
# n-R5s67                              0.033966                            0.0
# n-R5s68                              0.000000                            0.0
# n-R5s8                               0.000000                            0.0
# n-R5s87                              0.391113                            0.0
#
#                Adventitial fibroblast_Hurskainen2021_P14  \
# 0610005C13Rik                                        0.0
# 0610007C21Rik                                        0.0
# 0610007L01Rik                                        0.0
# 0610007N19Rik                                        0.0
# 0610007P08Rik                                        0.0
# ...                                                  ...
# n-R5s54                                              0.0
# n-R5s67                                              0.0
# n-R5s68                                              0.0
# n-R5s8                                               0.0
# n-R5s87                                              0.0
#
#                Adventitial fibroblast_Hurskainen2021_P3  \
# 0610005C13Rik                                  2.119141
# 0610007C21Rik                                  0.000000
# 0610007L01Rik                                  0.000000
# 0610007N19Rik                                  0.000000
# 0610007P08Rik                                  0.000000
# ...                                                 ...
# n-R5s54                                        0.000000
# n-R5s67                                        0.000000
# n-R5s68                                        0.000000
# n-R5s8                                         0.000000
# n-R5s87                                        0.000000
#
#                Adventitial fibroblast_Hurskainen2021_P7  \
# 0610005C13Rik                                  1.183594
# 0610007C21Rik                                  0.000000
# 0610007L01Rik                                  0.000000
# 0610007N19Rik                                  0.000000
# 0610007P08Rik                                  0.000000
# ...                                                 ...
# n-R5s54                                        0.000000
# n-R5s67                                        0.000000
# n-R5s68                                        0.000000
# n-R5s8                                         0.000000
# n-R5s87                                        0.000000
#
#                Adventitial fibroblast_TMS_18m  Adventitial fibroblast_TMS_24m  \
# 0610005C13Rik                        0.000000                        0.000000
# 0610007C21Rik                      325.000000                      375.750000
# 0610007L01Rik                      136.000000                      129.000000
# 0610007N19Rik                      189.500000                      211.750000
# 0610007P08Rik                        5.925781                        5.886719
# ...                                       ...                             ...
# n-R5s54                              0.000000                        0.000000
# n-R5s67                              0.000000                        0.000000
# n-R5s68                              0.000000                        0.000000
# n-R5s8                               0.000000                        0.000000
# n-R5s87                              0.000000                        0.000000
#
#                Adventitial fibroblast_TMS_3m  Airway smooth muscle_ACZ_P21  \
# 0610005C13Rik                        0.00000                      1.085938
# 0610007C21Rik                      350.25000                      0.000000
# 0610007L01Rik                      143.87500                      0.000000
# 0610007N19Rik                      198.25000                      0.000000
# 0610007P08Rik                       51.71875                      0.000000
# ...                                      ...                           ...
# n-R5s54                              0.00000                      0.018829
# n-R5s67                              0.00000                      0.538574
# n-R5s68                              0.00000                      0.000000
# n-R5s8                               0.00000                      0.000000
# n-R5s87                              0.00000                      0.000000
#
#                Airway smooth muscle_Hurskainen2021_P14  ...  \
# 0610005C13Rik                                 2.802734  ...
# 0610007C21Rik                                 0.000000  ...
# 0610007L01Rik                                 0.000000  ...
# 0610007N19Rik                                 0.000000  ...
# 0610007P08Rik                                 0.000000  ...
# ...                                                ...  ...
# n-R5s54                                       0.000000  ...
# n-R5s67                                       0.000000  ...
# n-R5s68                                       0.000000  ...
# n-R5s8                                        0.000000  ...
# n-R5s87                                       0.000000  ...
#
#                neutrophil_ACZ_E18.5  neutrophil_ACZ_P1  neutrophil_ACZ_P21  \
# 0610005C13Rik              0.309814           0.010681                 0.0
# 0610007C21Rik              0.000000           0.000000                 0.0
# 0610007L01Rik              0.000000           0.000000                 0.0
# 0610007N19Rik              0.000000           0.000000                 0.0
# 0610007P08Rik              0.000000           0.000000                 0.0
# ...                             ...                ...                 ...
# n-R5s54                    0.015053           0.000000                 0.0
# n-R5s67                    0.000000           0.000000                 0.0
# n-R5s68                    0.000000           1.734375                 0.0
# n-R5s8                     0.000000           0.000000                 0.0
# n-R5s87                    0.000000           0.210571                 0.0
#
#                neutrophil_ACZ_P7  neutrophil_Hurskainen2021_P14  \
# 0610005C13Rik           0.008118                            0.0
# 0610007C21Rik           0.000000                            0.0
# 0610007L01Rik           0.000000                            0.0
# 0610007N19Rik           0.000000                            0.0
# 0610007P08Rik           0.000000                            0.0
# ...                          ...                            ...
# n-R5s54                 0.000000                            0.0
# n-R5s67                 0.000000                            0.0
# n-R5s68                 2.335938                            0.0
# n-R5s8                  0.000000                            0.0
# n-R5s87                 0.000000                            0.0
#
#                neutrophil_Hurskainen2021_P3  neutrophil_Hurskainen2021_P7  \
# 0610005C13Rik                           0.0                           0.0
# 0610007C21Rik                           0.0                           0.0
# 0610007L01Rik                           0.0                           0.0
# 0610007N19Rik                           0.0                           0.0
# 0610007P08Rik                           0.0                           0.0
# ...                                     ...                           ...
# n-R5s54                                 0.0                           0.0
# n-R5s67                                 0.0                           0.0
# n-R5s68                                 0.0                           0.0
# n-R5s8                                  0.0                           0.0
# n-R5s87                                 0.0                           0.0
#
#                neutrophil_TMS_18m  neutrophil_TMS_24m  neutrophil_TMS_3m
# 0610005C13Rik              0.0000              0.0000           0.000000
# 0610007C21Rik            109.1875             54.6875          31.390625
# 0610007L01Rik             79.6250            169.0000           0.000000
# 0610007N19Rik              0.0000              0.0000           0.000000
# 0610007P08Rik              0.0000              0.0000           0.000000
# ...                           ...                 ...                ...
# n-R5s54                    0.0000              0.0000           0.000000
# n-R5s67                    0.0000              0.0000           0.000000
# n-R5s68                    0.0000              0.0000           0.000000
# n-R5s8                     0.0000              0.0000           0.000000
# n-R5s87                    0.0000              0.0000           0.000000
#
# [29781 rows x 308 columns]

# %%
all_celltypes = []
dt_combinations = []  # dataset and timepoint combinations

for column_name in filtered_df.columns:
    celltype = column_name.split("_")[0]
    dataset_timepoint = column_name.split(celltype+"_")[1]
    if celltype not in all_celltypes:
        all_celltypes.append(celltype)
    if dataset_timepoint not in dt_combinations:
        dt_combinations.append(dataset_timepoint)

# %%
all_celltypes
dt_combinations
# Out:
# ['ACZ_P21',
#  'ACZ_P7',
#  'Hurskainen2021_P14',
#  'Hurskainen2021_P3',
#  'Hurskainen2021_P7',
#  'TMS_18m',
#  'TMS_24m',
#  'TMS_3m',
#  'ACZ_E18.5',
#  'ACZ_P1']

# %%
expression = {}
for dt in dt_combinations:
    expression[dt] = {}
    for ct in all_celltypes:
        name = "_".join([ct,dt])
        if name not in filtered_df.columns:
            exp_value = -1
        else:
            exp_value = filtered_df[name].values[0]
        expression[dt][ct] = exp_value

# %%
json.loads(expression)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 json.loads(expression)
#
# File /opt/anaconda3/lib/python3.8/json/__init__.py:341, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339 else:
#     340     if not isinstance(s, (bytes, bytearray)):
# --> 341         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                         f'not {s.__class__.__name__}')
#     343     s = s.decode(detect_encoding(s), 'surrogatepass')
#     345 if "encoding" in kw:
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict

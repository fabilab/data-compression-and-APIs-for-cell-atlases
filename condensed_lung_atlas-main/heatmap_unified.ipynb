# %%
import h5py
import numpy as np
import pandas as pd
import scanpy as sc
from scipy.cluster.hierarchy import linkage,leaves_list, dendrogram
from scipy.spatial.distance import pdist, euclidean
from scipy.special import comb
import re

# %%
# gives the name of dataset we want as an input
# celltype / celltype_dataset / celltype_dataset_timepoint
def read_file(df_type):
    with h5py.File('./output/condensed_lung_atlas_in_cpm.h5',"r") as h5_data:
    
        df = pd.DataFrame(
                data=np.array(h5_data[df_type]['gene_expression_average']['block0_values']).astype(np.float32),
                index=np.array(h5_data[df_type]['gene_expression_average']['axis1'].asstr()),
                columns=np.array(h5_data[df_type]['gene_expression_average']['axis0'].asstr()),
            ).T
    return df

# %%
df = read_file('celltype_dataset_timepoint')
gene = 'Car4'
filtered_df = df.filter(items=[gene],axis=0)
filtered_df
# Out:
#       Adventitial fibroblast_ACZ_P21  Adventitial fibroblast_ACZ_P7  \
# Car4                        0.015945                            0.0
#
#       Adventitial fibroblast_Hurskainen2021_P14  \
# Car4                                   7.019531
#
#       Adventitial fibroblast_Hurskainen2021_P3  \
# Car4                                  6.179688
#
#       Adventitial fibroblast_Hurskainen2021_P7  \
# Car4                                  9.023438
#
#       Adventitial fibroblast_TMS_18m  Adventitial fibroblast_TMS_24m  \
# Car4                        2.792969                       13.703125
#
#       Adventitial fibroblast_TMS_3m  Airway smooth muscle_ACZ_P21  \
# Car4                       4.105469                           0.0
#
#       Airway smooth muscle_Hurskainen2021_P14  ...  neutrophil_ACZ_E18.5  \
# Car4                                14.140625  ...                   0.0
#
#       neutrophil_ACZ_P1  neutrophil_ACZ_P21  neutrophil_ACZ_P7  \
# Car4           6.242188               0.056          26.359375
#
#       neutrophil_Hurskainen2021_P14  neutrophil_Hurskainen2021_P3  \
# Car4                       39.53125                     25.859375
#
#       neutrophil_Hurskainen2021_P7  neutrophil_TMS_18m  neutrophil_TMS_24m  \
# Car4                      5.808594             8.78125                 0.0
#
#       neutrophil_TMS_3m
# Car4          27.359375
#
# [1 rows x 308 columns]

# %%
all_celltypes = []
dt_combinations = []  # dataset and timepoint combinations

for column_name in filtered_df.columns:
    celltype = column_name.split("_")[0]
    dataset_timepoint = column_name.split(celltype+"_")[1]
    if celltype not in all_celltypes:
        all_celltypes.append(celltype)
    if dataset_timepoint not in dt_combinations:
        dt_combinations.append(dataset_timepoint)

# %%
all_celltypes
dt_combinations
# Out:
# ['ACZ_P21',
#  'ACZ_P7',
#  'Hurskainen2021_P14',
#  'Hurskainen2021_P3',
#  'Hurskainen2021_P7',
#  'TMS_18m',
#  'TMS_24m',
#  'TMS_3m',
#  'ACZ_E18.5',
#  'ACZ_P1']

# %%
expression = {}
for dt in dt_combinations:
    expression[dt] = {}
    for ct in all_celltypes:
        name = "_".join([ct,dt])
        if name not in filtered_df.columns:
            exp_value = -1
        else:
            exp_value = filtered_df[name].values[0]
        expression[dt][ct] = exp_value

# %%
expression
# Out:
# {'ACZ_P21': {'Adventitial fibroblast': 0.015945435,
#   'Airway smooth muscle': 0.0,
#   'Alveolar fibroblast': 26.765625,
#   'Alveolar type II': 0.0,
#   'Alveolar type I': 0.0,
#   'Arterial EC II': 0.0,
#   'Arterial EC I': 0.0,
#   'B cell': 13.0625,
#   'Car4+ capillaries': 7268.0,
#   'DC III': 0.0,
#   'DC II': 0.0,
#   'DC I': 120.1875,
#   'Early Car4- capillaries': 310.0,
#   'Early adventitial fibroblast': 0.0,
#   'Early airway smooth muscle': 0.0,
#   'Early alveolar fibroblast': 0.0,
#   'Fibroblast precursor': -1,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 585.5,
#   'Lymphatic EC': 0.0,
#   'Mac III': 1047.0,
#   'Mac II': 0.0,
#   'Mac IV': 8.203125,
#   'Mac I': -1,
#   'Mac V': 0.0019779205,
#   'Myofibroblast and smooth muscle precursor': -1,
#   'Myofibroblast': -1,
#   'NK cell': 12.9140625,
#   'Nonproliferative embryonic EC': -1,
#   'Pericyte': 0.0034923553,
#   'Proliferating fibroblast': -1,
#   'Proliferating myofibroblast': -1,
#   'Proliferating pericyte': -1,
#   'Proliferative EC': 550.5,
#   'Striated muscle': 0.0,
#   'T cell': 0.19689941,
#   'Vascular smooth muscle': 4.6679688,
#   'Venous EC': 0.0,
#   'basophil': 0.0,
#   'mast cell': -1,
#   'neutrophil': 0.055999756},
#  'ACZ_P7': {'Adventitial fibroblast': 0.0,
#   'Airway smooth muscle': -1,
#   'Alveolar fibroblast': -1,
#   'Alveolar type II': 80.6875,
#   'Alveolar type I': 1059.0,
#   'Arterial EC II': 0.0,
#   'Arterial EC I': 15.625,
#   'B cell': 0.0,
#   'Car4+ capillaries': 5444.0,
#   'DC III': 0.0,
#   'DC II': 0.45043945,
#   'DC I': 0.0,
#   'Early Car4- capillaries': 268.0,
#   'Early adventitial fibroblast': 0.0,
#   'Early airway smooth muscle': 0.0,
#   'Early alveolar fibroblast': 0.3305664,
#   'Fibroblast precursor': -1,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 369.75,
#   'Lymphatic EC': 2.2207031,
#   'Mac III': 804.5,
#   'Mac II': 1.2636719,
#   'Mac IV': 35.96875,
#   'Mac I': -1,
#   'Mac V': 0.18273926,
#   'Myofibroblast and smooth muscle precursor': 0.0,
#   'Myofibroblast': 0.005306244,
#   'NK cell': 0.0,
#   'Nonproliferative embryonic EC': 0.0,
#   'Pericyte': 3.2226562,
#   'Proliferating fibroblast': 0.0,
#   'Proliferating myofibroblast': 0.0,
#   'Proliferating pericyte': 0.0,
#   'Proliferative EC': 197.0,
#   'Striated muscle': 0.0,
#   'T cell': 0.101257324,
#   'Vascular smooth muscle': 0.0,
#   'Venous EC': 75.0625,
#   'basophil': 0.0,
#   'mast cell': 0.0,
#   'neutrophil': 26.359375},
#  'Hurskainen2021_P14': {'Adventitial fibroblast': 7.0195312,
#   'Airway smooth muscle': 14.140625,
#   'Alveolar fibroblast': 15.234375,
#   'Alveolar type II': 10.2578125,
#   'Alveolar type I': 25.546875,
#   'Arterial EC II': 0.0,
#   'Arterial EC I': 23.203125,
#   'B cell': 15.3515625,
#   'Car4+ capillaries': 430.5,
#   'DC III': 0.0,
#   'DC II': 24.40625,
#   'DC I': 39.65625,
#   'Early Car4- capillaries': -1,
#   'Early adventitial fibroblast': 15.5234375,
#   'Early airway smooth muscle': 10.4921875,
#   'Early alveolar fibroblast': 0.0,
#   'Fibroblast precursor': -1,
#   'IL cell': 60.96875,
#   'Late Car4- capillaries': 220.75,
#   'Lymphatic EC': 10.234375,
#   'Mac III': 356.75,
#   'Mac II': -1,
#   'Mac IV': 7.7265625,
#   'Mac I': -1,
#   'Mac V': 6.9765625,
#   'Myofibroblast and smooth muscle precursor': -1,
#   'Myofibroblast': 10.796875,
#   'NK cell': 11.53125,
#   'Nonproliferative embryonic EC': -1,
#   'Pericyte': 7.8867188,
#   'Proliferating fibroblast': -1,
#   'Proliferating myofibroblast': 0.0,
#   'Proliferating pericyte': 0.0,
#   'Proliferative EC': 0.0,
#   'Striated muscle': 0.0,
#   'T cell': 12.84375,
#   'Vascular smooth muscle': 10.015625,
#   'Venous EC': 17.046875,
#   'basophil': 33.65625,
#   'mast cell': -1,
#   'neutrophil': 39.53125},
#  'Hurskainen2021_P3': {'Adventitial fibroblast': 6.1796875,
#   'Airway smooth muscle': 3.1347656,
#   'Alveolar fibroblast': -1,
#   'Alveolar type II': 7.4960938,
#   'Alveolar type I': 9.328125,
#   'Arterial EC II': 0.0,
#   'Arterial EC I': 10.453125,
#   'B cell': 5.609375,
#   'Car4+ capillaries': 606.0,
#   'DC III': 0.0,
#   'DC II': 0.0,
#   'DC I': 0.0,
#   'Early Car4- capillaries': 220.125,
#   'Early adventitial fibroblast': 10.2109375,
#   'Early airway smooth muscle': 7.1875,
#   'Early alveolar fibroblast': 42.84375,
#   'Fibroblast precursor': 0.0,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 304.0,
#   'Lymphatic EC': 24.65625,
#   'Mac III': 233.75,
#   'Mac II': -1,
#   'Mac IV': 14.546875,
#   'Mac I': -1,
#   'Mac V': 13.984375,
#   'Myofibroblast and smooth muscle precursor': -1,
#   'Myofibroblast': 12.6171875,
#   'NK cell': 29.34375,
#   'Nonproliferative embryonic EC': -1,
#   'Pericyte': 8.0546875,
#   'Proliferating fibroblast': 10.125,
#   'Proliferating myofibroblast': 6.9609375,
#   'Proliferating pericyte': -1,
#   'Proliferative EC': 112.0625,
#   'Striated muscle': 46.9375,
#   'T cell': 25.65625,
#   'Vascular smooth muscle': 0.0,
#   'Venous EC': 13.609375,
#   'basophil': 0.0,
#   'mast cell': -1,
#   'neutrophil': 25.859375},
#  'Hurskainen2021_P7': {'Adventitial fibroblast': 9.0234375,
#   'Airway smooth muscle': 0.0,
#   'Alveolar fibroblast': -1,
#   'Alveolar type II': 8.5390625,
#   'Alveolar type I': 3.7792969,
#   'Arterial EC II': 0.0,
#   'Arterial EC I': 17.359375,
#   'B cell': 8.3984375,
#   'Car4+ capillaries': 540.5,
#   'DC III': 31.125,
#   'DC II': 23.0625,
#   'DC I': 18.59375,
#   'Early Car4- capillaries': 195.625,
#   'Early adventitial fibroblast': 11.7734375,
#   'Early airway smooth muscle': 8.8515625,
#   'Early alveolar fibroblast': 4.6914062,
#   'Fibroblast precursor': 0.0,
#   'IL cell': 10.5859375,
#   'Late Car4- capillaries': 199.875,
#   'Lymphatic EC': 9.828125,
#   'Mac III': 279.75,
#   'Mac II': -1,
#   'Mac IV': 5.0546875,
#   'Mac I': -1,
#   'Mac V': 12.5546875,
#   'Myofibroblast and smooth muscle precursor': -1,
#   'Myofibroblast': 8.015625,
#   'NK cell': 0.0,
#   'Nonproliferative embryonic EC': -1,
#   'Pericyte': 17.78125,
#   'Proliferating fibroblast': 0.0,
#   'Proliferating myofibroblast': 8.359375,
#   'Proliferating pericyte': -1,
#   'Proliferative EC': 45.0,
#   'Striated muscle': 0.0,
#   'T cell': 12.296875,
#   'Vascular smooth muscle': 5.859375,
#   'Venous EC': 0.0,
#   'basophil': 11.9609375,
#   'mast cell': -1,
#   'neutrophil': 5.8085938},
#  'TMS_18m': {'Adventitial fibroblast': 2.7929688,
#   'Airway smooth muscle': 0.0,
#   'Alveolar fibroblast': 7.875,
#   'Alveolar type II': 19.015625,
#   'Alveolar type I': -1,
#   'Arterial EC II': 0.0,
#   'Arterial EC I': -1,
#   'B cell': 2.6972656,
#   'Car4+ capillaries': 678.0,
#   'DC III': 0.0,
#   'DC II': 0.0,
#   'DC I': 4.5664062,
#   'Early Car4- capillaries': -1,
#   'Early adventitial fibroblast': -1,
#   'Early airway smooth muscle': -1,
#   'Early alveolar fibroblast': -1,
#   'Fibroblast precursor': -1,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 380.25,
#   'Lymphatic EC': 91.5625,
#   'Mac III': -1,
#   'Mac II': -1,
#   'Mac IV': 0.0,
#   'Mac I': -1,
#   'Mac V': 0.0,
#   'Myofibroblast and smooth muscle precursor': -1,
#   'Myofibroblast': -1,
#   'NK cell': 0.0,
#   'Nonproliferative embryonic EC': -1,
#   'Pericyte': 0.0,
#   'Proliferating fibroblast': -1,
#   'Proliferating myofibroblast': -1,
#   'Proliferating pericyte': -1,
#   'Proliferative EC': -1,
#   'Striated muscle': 0.0,
#   'T cell': 0.38208008,
#   'Vascular smooth muscle': 0.0,
#   'Venous EC': -1,
#   'basophil': -1,
#   'mast cell': -1,
#   'neutrophil': 8.78125},
#  'TMS_24m': {'Adventitial fibroblast': 13.703125,
#   'Airway smooth muscle': 0.0,
#   'Alveolar fibroblast': 19.671875,
#   'Alveolar type II': 29.96875,
#   'Alveolar type I': -1,
#   'Arterial EC II': -1,
#   'Arterial EC I': 0.0,
#   'B cell': 1.2558594,
#   'Car4+ capillaries': 1394.0,
#   'DC III': 0.0,
#   'DC II': 2.1933594,
#   'DC I': 5.6679688,
#   'Early Car4- capillaries': -1,
#   'Early adventitial fibroblast': -1,
#   'Early airway smooth muscle': -1,
#   'Early alveolar fibroblast': 0.0,
#   'Fibroblast precursor': -1,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 475.25,
#   'Lymphatic EC': 0.0,
#   'Mac III': -1,
#   'Mac II': -1,
#   'Mac IV': 0.0,
#   'Mac I': -1,
#   'Mac V': 3.9824219,
#   'Myofibroblast and smooth muscle precursor': -1,
#   'Myofibroblast': -1,
#   'NK cell': 0.0,
#   'Nonproliferative embryonic EC': 0.0,
#   'Pericyte': 36.1875,
#   'Proliferating fibroblast': -1,
#   'Proliferating myofibroblast': -1,
#   'Proliferating pericyte': -1,
#   'Proliferative EC': -1,
#   'Striated muscle': 406.25,
#   'T cell': 0.38745117,
#   'Vascular smooth muscle': 0.0,
#   'Venous EC': -1,
#   'basophil': -1,
#   'mast cell': -1,
#   'neutrophil': 0.0},
#  'TMS_3m': {'Adventitial fibroblast': 4.1054688,
#   'Airway smooth muscle': 9.8359375,
#   'Alveolar fibroblast': 6.2304688,
#   'Alveolar type II': 19.65625,
#   'Alveolar type I': 0.0,
#   'Arterial EC II': 30.75,
#   'Arterial EC I': -1,
#   'B cell': 2.2480469,
#   'Car4+ capillaries': 707.0,
#   'DC III': 0.0,
#   'DC II': 6.921875,
#   'DC I': 18.171875,
#   'Early Car4- capillaries': -1,
#   'Early adventitial fibroblast': -1,
#   'Early airway smooth muscle': -1,
#   'Early alveolar fibroblast': -1,
#   'Fibroblast precursor': -1,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 272.5,
#   'Lymphatic EC': 7.0859375,
#   'Mac III': -1,
#   'Mac II': -1,
#   'Mac IV': 176.125,
#   'Mac I': -1,
#   'Mac V': 2.7929688,
#   'Myofibroblast and smooth muscle precursor': 0.0,
#   'Myofibroblast': -1,
#   'NK cell': 2.9453125,
#   'Nonproliferative embryonic EC': 0.0,
#   'Pericyte': 37.03125,
#   'Proliferating fibroblast': -1,
#   'Proliferating myofibroblast': -1,
#   'Proliferating pericyte': -1,
#   'Proliferative EC': -1,
#   'Striated muscle': -1,
#   'T cell': 28.5,
#   'Vascular smooth muscle': 0.0,
#   'Venous EC': 0.0,
#   'basophil': -1,
#   'mast cell': -1,
#   'neutrophil': 27.359375},
#  'ACZ_E18.5': {'Adventitial fibroblast': -1,
#   'Airway smooth muscle': -1,
#   'Alveolar fibroblast': -1,
#   'Alveolar type II': 0.0,
#   'Alveolar type I': 0.0,
#   'Arterial EC II': 0.08355713,
#   'Arterial EC I': 0.0,
#   'B cell': 0.0,
#   'Car4+ capillaries': -1,
#   'DC III': -1,
#   'DC II': 0.0,
#   'DC I': 0.0,
#   'Early Car4- capillaries': 727.0,
#   'Early adventitial fibroblast': 0.02041626,
#   'Early airway smooth muscle': -1,
#   'Early alveolar fibroblast': 0.0,
#   'Fibroblast precursor': 0.036102295,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 47.625,
#   'Lymphatic EC': 0.0,
#   'Mac III': 419.0,
#   'Mac II': 80.125,
#   'Mac IV': 0.0,
#   'Mac I': 38.375,
#   'Mac V': 0.030136108,
#   'Myofibroblast and smooth muscle precursor': 0.016036987,
#   'Myofibroblast': 0.0,
#   'NK cell': 0.0,
#   'Nonproliferative embryonic EC': 51.65625,
#   'Pericyte': 0.0,
#   'Proliferating fibroblast': 0.0,
#   'Proliferating myofibroblast': 0.0,
#   'Proliferating pericyte': 0.0,
#   'Proliferative EC': 34.375,
#   'Striated muscle': -1,
#   'T cell': 0.0,
#   'Vascular smooth muscle': 0.0,
#   'Venous EC': 0.0,
#   'basophil': 0.0,
#   'mast cell': 0.0,
#   'neutrophil': 0.0},
#  'ACZ_P1': {'Adventitial fibroblast': -1,
#   'Airway smooth muscle': -1,
#   'Alveolar fibroblast': -1,
#   'Alveolar type II': 32.34375,
#   'Alveolar type I': 632.0,
#   'Arterial EC II': 0.0,
#   'Arterial EC I': 0.0,
#   'B cell': 0.0074920654,
#   'Car4+ capillaries': 3916.0,
#   'DC III': 0.0,
#   'DC II': 0.0,
#   'DC I': 0.0,
#   'Early Car4- capillaries': 242.875,
#   'Early adventitial fibroblast': 1.5507812,
#   'Early airway smooth muscle': 0.027999878,
#   'Early alveolar fibroblast': 0.10986328,
#   'Fibroblast precursor': 0.0,
#   'IL cell': 0.0,
#   'Late Car4- capillaries': 268.25,
#   'Lymphatic EC': 9.875,
#   'Mac III': 694.0,
#   'Mac II': 18.46875,
#   'Mac IV': 0.0,
#   'Mac I': 0.0,
#   'Mac V': 0.0062217712,
#   'Myofibroblast and smooth muscle precursor': 0.0,
#   'Myofibroblast': 0.0,
#   'NK cell': 0.0,
#   'Nonproliferative embryonic EC': 4.8007812,
#   'Pericyte': 0.0,
#   'Proliferating fibroblast': 0.0,
#   'Proliferating myofibroblast': 0.0,
#   'Proliferating pericyte': -1,
#   'Proliferative EC': 159.625,
#   'Striated muscle': -1,
#   'T cell': 0.043640137,
#   'Vascular smooth muscle': 0.0,
#   'Venous EC': 23.515625,
#   'basophil': 0.0,
#   'mast cell': 0.0,
#   'neutrophil': 6.2421875}}
